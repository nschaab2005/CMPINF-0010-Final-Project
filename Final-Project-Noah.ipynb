# %% [markdown]
# ## Introduction
#
# For this final project our group decided to look at the overarching metric of quality of life. When any person is looking for a place to live there are a variety of aspects they look at to determine their satisfaction with the area.. All of these possible submetrics that you can think of relate to the quality of the person's experience living there. The cost of living, the amount of green space you have access to, or the safety of the area all contributes to the individual's happiness with the area. For this project our group determined three submetrics to go along with the overall metric. These submetrics are crime rates, green space, and home values.

# %% [markdown]
# ## The Metric
#
# For my part of the project I will be analyzing home values across various neighborhoods in Pittsburgh. The reason I chose this submetric is because the cost of living within an area is one of the first things people have in mind when picking an ideal area to live. The cost of one's living space is vital information when making the big decision of where to settle down. Looking at the median home values within the neighborhoods can be a good indicator to someone on where to live. A high home value can raise concern over affordability but a low value can raise concern over quality of living space. The goal of my part of the project is to find a neighborhood where the home value is not too expensive but also not too low to signify poor living conditions. For picking the ideal home value I am going to base it off of the average base salary in the city of Pittsburgh which is around 76,000. For a base salary of 76,000 the suggester home value was around the lower 100,000.
#
# **Link to data:** https://data.wprdc.org/dataset/40188e1c-6d2e-4f20-9391-607bd3054949/resource/9890875b-c1d1-4e64-8fc9-a4a8dc433745/download/housing.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

snap_data = pd.read_csv("pitt_snap_data.csv") #load data
home_value_data = snap_data.iloc[:, [1, 22]] #grab the columns 'neighborhood' and 'median home value (2010)'
filtered_data = home_value_data.dropna(subset = ['Median Home Value (2010)']) #get rid of NaN values
filtered_data['Median Home Value (2010)'] = pd.to_numeric(
    filtered_data['Median Home Value (2010)'].str.replace(',', '').str.strip("$"),
    errors="coerce")

filtered_data = filtered_data.sort_values('Median Home Value (2010)')
# Out:
# /scratch/slurm-11890/ipykernel_248843/3652242823.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Median Home Value (2010)'] = pd.to_numeric(

# %%
filtered_data.tail(10).plot(x = 'Neighborhood', kind = 'bar', title = 'Low Home Values')
plt.xlabel('Neighborhoods')
plt.ylabel('Median Home Value (2010')
plt.figure(figsize=(15, 8))
plt.show()

# %%
filtered_data.head(10).plot(x = 'Neighborhood', kind = 'bar', title = "High Home Values")
plt.xlabel('Neighborhoods')
plt.ylabel('Median Home Value (2010')
plt.figure(figsize=(15, 8))
plt.show()

# %%
filtered_data.iloc[50:70].plot(x = 'Neighborhood', kind = 'bar', title = "Good Home Values")
plt.xlabel('Neighborhoods')
plt.ylabel('Median Home Value (2010')
plt.figure(figsize=(15, 8))
plt.show()

# %%
filtered_data[50:70]
# Out:
#             Neighborhood  Median Home Value (2010)
# 89               Windgap                     78200
# 6      Bedford Dwellings                     81100
# 12      Brighton Heights                     81433
# 13             Brookline                     82150
# 78       Stanton Heights                     86700
# 51           Morningside                     89700
# 66             Ridgemont                     90500
# 36            Greenfield                     90900
# 9             Bloomfield                     92840
# 88              Westwood                     93700
# 80           Summer Hill                     94400
# 23      Crawford-Roberts                     94600
# 63    Point Breeze North                     99500
# 24      Duquesne Heights                    100500
# 48            Manchester                    101300
# 58               Oakwood                    108500
# 81        Swisshelm Park                    108600
# ...

# %% [markdown]
# ## Data Summary
#
# For the above graphs you can see how various neighborhoods rank with their median home values. The first graph shows the top ten most expensive neighborhoods in terms of median home value. Squirrel Hill North is the most expensive averaging a median home value of 344,990 which would be way too expensive. Other neighborhoods towards the top include North Oakland, Shadyside, Point Breeze, Squirrel Hill South, Regent Square, Highland Park, Friendship, Strip District, and the South Side Flats. As for the second graph it shows the top ten lease expensive neighrborhoods in terms of median home value with Bluff being the cheapest. This graph also includes West End, Homewood West, Larimer, Homewood North, Beltzhoover, Knoxville, East Hills, St. Clair, and Allentown. The third graph shows home values that are recommended and affordable for a base salary of 76,000. Some of these neighborhoods include Banksville, Oakwood, Bloomfield, Brighton Heights, and many more.

# %% [markdown]
# ## Conclusion
#
# Overall while there are quite a few neighborhoods that would not be ideal due to being too expensive or too cheap, there are still plenty of other neighborhoods that can work out for the future home owner. The one thing with using home value as a metric as that every individual has a different budget or lifestyle they like to live which could determine what exact homevalue they may aim for. While a lot of what may be the best neighborhood comes down to personal preferrence when using the submetric of homevalues, there are a clear group of neighborhoods that can fall into an ideal range of what people look for.
